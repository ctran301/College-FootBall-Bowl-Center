# %%
import pandas as pd

# %%
playersCSV = "player_stats.csv"
gameCSV= "game_stats.csv"

players = pd.read_csv(playersCSV, encoding="utf-8")
players.head()
# Out:
#    GameId              team    player  Passing - Attempts  \
# 0   27067  UTSA Roadrunners     Sturm                26.0
# 1   27067  New Mexico Lobos    Jordan                 4.0
# 2   27067  New Mexico Lobos   Apodaca                 2.0
# 3   27067  UTSA Roadrunners  Williams                 NaN
# 4   27067  UTSA Roadrunners    Rhodes                 NaN
#
#    Passing - Completion Pct  Passing - Completions  Passing - Interceptions  \
# 0                      38.5                   10.0                      1.0
# 1                      75.0                    3.0                      0.0
# 2                       0.0                    0.0                      0.0
# 3                       NaN                    NaN                      NaN
# 4                       NaN                    NaN                      NaN
#
#    Passing - Passing Touchdowns  Passing - Passing Yards  Passing - QB Rating  \
# ...

# %%
games = pd.read_csv(gameCSV, encoding="utf-8")
games.head()
# Out:
#    Year  Attendance                       Host               Away Team  \
# 0  2001       40139   Marshall Thundering Herd   East Carolina Pirates
# 1  2011       65256               Baylor Bears      Washington Huskies
# 2  2016       24975        Colorado State Rams           Idaho Vandals
# 3  2015       36811  Arkansas State Red Wolves          Toledo Rockets
# 4  2015       31289       Virginia Tech Hokies  Tulsa Golden Hurricane
#
#                    Home Team               Bowl     id  Home Bowl Scores  \
# 0   Marshall Thundering Herd          GMAC Bowl   2885                64
# 1               Baylor Bears         Alamo Bowl  17746                67
# 2        Colorado State Rams  Idaho Potato Bowl  27073                50
# 3  Arkansas State Red Wolves       GoDaddy Bowl  23972                44
# 4       Virginia Tech Hokies  Independence Bowl  25533                55
#
#    Away Bowl Scores  Home Season Wins  Home Season Losses  Away Season Wins  \
# ...
